# %%
from datasets import load_dataset

# Load the dataset in streaming mode
ds = load_dataset("Yeshenglong/InternSpatial", split="train", streaming=True)
test_data = ds.to_pandas()

# Get the first sample immediately
# one_sample = next(iter(ds))

# # Now you can access keys directly
# print(one_sample.keys())
# print(one_sample['scene_id'])
